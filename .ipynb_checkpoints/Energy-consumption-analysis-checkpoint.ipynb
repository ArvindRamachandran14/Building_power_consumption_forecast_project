# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_path = '/Users/ArvindRamachadran/Dropbox (ASU)/power-laws-forecasting-energy-data/'

# %%
df_holidays = pd.read_csv(data_path+'power-laws-forecasting-energy-consumption-holidays.csv', delimiter=';')
df_holidays['count'] =1

# %%
df_energy_consumption = pd.read_csv(data_path+'power-laws-forecasting-energy-consumption-training-data.csv', delimiter=';')
df_energy_consumption['count']=1

# %%
df_weather_data = pd.read_csv(data_path+'power-laws-forecasting-energy-consumption-weather.csv', delimiter=';')
df_weather_data['count']=1

# %%
df_meta_data = pd.read_csv(data_path+'power-laws-forecasting-energy-consumption-metadata.csv',delimiter=";")
df_meta_data['count']=1

# %%
df_test_data = pd.read_csv(data_path+'power-laws-forecasting-energy-consumption-test-data.csv',delimiter=";")

# %%
df_submission = pd.read_csv(data_path+'power-laws-forecasting-energy-consumption-submission-forecast-period.csv',delimiter=";")

# %%
df_weather_data['Timestamp'] = pd.to_datetime(df_weather_data['Timestamp'])

# %%
df_energy_consumption['Timestamp'] = pd.to_datetime(df_energy_consumption['Timestamp'])

# %%
df_holidays['Date'] = pd.to_datetime(df_holidays['Date'])

# %%
df_weather_data['Timestamp'].sort_values()
# Out:
# 894613    2013-01-01 13:00:00
# 1795946   2013-01-01 13:00:00
# 2969540   2013-01-01 13:00:00
# 934381    2013-01-01 13:00:00
# 2670340   2013-01-01 13:00:00
# 1768212   2013-01-01 13:00:00
# 647042    2013-01-01 13:00:00
# 2071094   2013-01-01 13:00:00
# 3517751   2013-01-01 13:00:00
# 3284107   2013-01-01 13:00:00
# 1561119   2013-01-01 13:00:00
# 1812786   2013-01-01 13:00:00
# 3284108   2013-01-01 13:00:00
# 1721340   2013-01-01 13:00:00
# 3003328   2013-01-01 13:00:00
# 3506186   2013-01-01 13:00:00
# 2977669   2013-01-01 14:00:00
# 399398    2013-01-01 14:00:00
# 1301083   2013-01-01 14:00:00
# 2024164   2013-01-01 14:00:00
# 3363916   2013-01-01 14:00:00
# 1575863   2013-01-01 14:00:00
# 2964269   2013-01-01 14:00:00
# 3540813   2013-01-01 14:00:00
# 1600385   2013-01-01 15:00:00
# 1608874   2013-01-01 15:00:00
# 1628872   2013-01-01 15:00:00
# 2694950   2013-01-01 15:00:00
# 3299570   2013-01-01 15:00:00
# 1763678   2013-01-01 15:00:00
#                   ...
# 2981922   2017-12-31 09:30:00
# 3506185   2017-12-31 09:30:00
# 473041    2017-12-31 09:30:00
# 1290603   2017-12-31 10:00:00
# 2055110   2017-12-31 10:00:00
# 877389    2017-12-31 10:00:00
# 2876337   2017-12-31 10:00:00
# 1536741   2017-12-31 10:00:00
# 3433737   2017-12-31 10:00:00
# 902992    2017-12-31 10:00:00
# 667704    2017-12-31 10:00:00
# 3303251   2017-12-31 10:00:00
# 1259849   2017-12-31 10:00:00
# 1879412   2017-12-31 10:00:00
# 2058187   2017-12-31 10:00:00
# 934380    2017-12-31 10:00:00
# 2071093   2017-12-31 10:00:00
# 1547229   2017-12-31 10:00:00
# 2300560   2017-12-31 10:00:00
# 3823971   2017-12-31 10:00:00
# 3529358   2017-12-31 10:00:00
# 339895    2017-12-31 10:30:00
# 3314587   2017-12-31 10:30:00
# 860653    2017-12-31 10:30:00
# 1847660   2017-12-31 10:30:00
# 3838313   2017-12-31 10:30:00
# 1728260   2017-12-31 10:30:00
# 2651087   2017-12-31 10:30:00
# 3334718   2017-12-31 10:30:00
# 1327820   2017-12-31 10:30:00
# Name: Timestamp, Length: 3957035, dtype: datetime64[ns]

# %%
#df_energy_consumption['Timestamp'].sort_values()

# %%
df_energy_consumption_site_grouped = df_energy_consumption.groupby(['SiteId'])
df_meta_data_site_grouped = df_meta_data.groupby(['SiteId'])
df_weather_data_site_grouped = df_weather_data.groupby(['SiteId'])

# %%
#df_energy_consumption_site_grouped.count()['count'].sort_values(ascending=False).head(15)

# %%
#df_weather_data_site_grouped.count()['count'].sort_values(ascending=False).head(15)

# %%
#df_weather_data.loc[df_weather_data['SiteId']==6]

# %%
site_max_energy = df_energy_consumption_site_grouped.mean()['Value'].idxmax()

# %%
site_max_weather_data = df_weather_data_site_grouped.count()['count'].idxmax()

# %%
sorted_mean_energy = list(df_energy_consumption_site_grouped.mean().sort_index()['Value'])

# %%
sorted_mean_surface = list(df_meta_data_site_grouped.mean().sort_index()['Surface'])

# %%
#df_weather_data.loc[(df_weather_data['SiteId']==6)].sort_values(by=['Timestamp'], ascending=False)

# %%
Sample_weather_data = df_weather_data.loc[(df_weather_data['SiteId']==6)
&(df_weather_data['Timestamp'].dt.day >=1)&(df_weather_data['Timestamp'].dt.day <=17)
&(df_weather_data['Timestamp'].dt.month == 9)&(df_weather_data['Timestamp'].dt.year == 2017)]

# %%
plt.figure(figsize=(12,6))
plt.plot(Sample_weather_data['Timestamp'], Sample_weather_data['Temperature'], 'ko')

# %%
Sample_energy_data = df_energy_consumption.loc[(df_energy_consumption['SiteId']==6)
&(df_energy_consumption['Timestamp'].dt.day >=1)&(df_energy_consumption['Timestamp'].dt.day<=17)
&(df_energy_consumption['Timestamp'].dt.month == 9)&(df_energy_consumption['Timestamp'].dt.year == 2017)]

# %%
fig = plt.figure(figsize=(12,6))
ax = fig.add_subplot(111)
ax_twin = ax.twinx()
ax.plot(Sample_energy_data['Timestamp'], Sample_energy_data['Value'], 'bo')
ax_twin.plot(Sample_weather_data['Timestamp'], Sample_weather_data['Temperature'], 'ro')
ax.set_xlabel('Datetime')
ax.set_ylabel('Energy consumed (Energy units)')
ax_twin.set_ylabel('Temperature (C)')
ax.set_title('A comparison of trends in energy consumption and weather in site 6 in September 2017')
plt.savefig('Energy-vs-temperature.pdf')

# %%
#plt.plot(sorted_surface, sorted_energy, 'ko')

# %%
plt.plot(df_meta_data_site_grouped.mean()['Surface'].sort_index, df_energy_consumption_site_grouped.mean()['Value'].sort_index, 'ko')

# %%
df_weather_data.loc[df_weather_data['SiteId']==site_max_weather_data].head()

# %%
plt.plot(df_energy_consumption.loc[df_energy_consumption["SiteId"]==93]['Timestamp'][:1000], df_energy_consumption.loc[df_energy_consumption["SiteId"]==93]['Value'][:1000], 'k-')

# %%
#df_energy_consumption.loc[df_energy_consumption["SiteId"]==302]

# %%
df_energy_consumption["datetime"] = pd.to_datetime(df_energy_consumption['Timestamp'], format='%Y-%M-%dT%H:%M:%S+00:00')
